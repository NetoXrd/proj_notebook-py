# %% [markdown]
# 01 - crie um programa que conte de zero até cinco

# %%
x = 0
while (x<=5):
    print(x)
    x += 1
# Out:
# 0
# 1
# 2
# 3
# 4
# 5

# %% [markdown]
# 02 - crie uma lista com cinco nomes e mostre cada um seus respctivos numeros

# %%
nome = []
nome=[
    "Gustavo",
    "Carlos",
    "Felipe",
    "Ana Luiza",
    "Maria Rita"]
x=0
while(x<=4):
    print(x,nome[x])
    x += 1
# Out:
# 0 Gustavo
# 1 Carlos
# 2 Felipe
# 3 Ana Luiza
# 4 Maria Rita

# %% [markdown]
# 03 - crie uma lista com cinco nomes e organize de modo alfabetico, mostrando os seus resprctivos mumeros:

# %%
nome = []
nome=[
    "Gustavo",
    "Carlos",
    "Felipe",
    "Ana Luiza",
    "Maria Rita"]
nome.sort()
x=0
while(x<=4):
    print(x,nome[x])
    x += 1
# Out:
# 0 Ana Luiza
# 1 Carlos
# 2 Felipe
# 3 Gustavo
# 4 Maria Rita
